# %%
import cv2
import os
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_path = "/home/wvillegas/datasets/DHARMaBuds/corpus-26000-bc/"

# %%
data_csv = pd.read_csv(data_path + 'corpus-26000.csv')

# %%
buds = data_csv.loc[data_csv['class'] == True]

# %%
buds.head()
# Out:
#   imageName imageOrigin  xBudCenter  yBudCenter  radio  class  type
# 0  0001.jpg    0001.jpg        2343        1745    100   True     2
# 1  0032.jpg    0002.jpg        2169        1661     77   True     1
# 2  0056.jpg    0003.jpg        2340        1828    124   True     2
# 3  0121.jpg    0004.jpg        2280        1540     90   True     2
# 4  0163.jpg    0005.jpg        2144        1840    146   True     1

# %%
img_height = 200
img_width = 200

# %%
for bud in buds['imageName']
    list_bud = []
    img = cv2.imread(data_path + bud)
    
    img = img.re

# %%
img=cv2.imread(data_path+'0032.jpg')
img

# %%
# Out:
# '0001.jpg'
